# %%
# !pip install textstat
# Out:
# ...
#   Using cached textstat-0.7.3-py3-none-any.whl (105 kB)
# ...
#   Using cached pyphen-0.13.2-py3-none-any.whl (2.0 MB)
# ...

# %%
import textstat as txt

# %%
import pandas as pd

# %%
df1 = pd.read_csv('/Users/mertcakir/Downloads/TURKEY_1YEAR.csv')

# %%
df1
# Out:
#                         versionCreated  \
# 0            2022-06-30 15:30:01+00:00
# 1            2022-06-30 15:13:03+00:00
# 2            2022-06-30 13:49:00+00:00
# 3            2022-06-30 13:24:32+00:00
# 4            2022-06-30 13:14:03+00:00
# 5            2022-06-30 12:51:00+00:00
# 6            2022-06-30 12:33:01+00:00
# 7            2022-06-30 11:44:17+00:00
# 8            2022-06-30 11:38:13+00:00
# 9            2022-06-30 11:22:01+00:00
# 10           2022-06-30 10:11:12+00:00
# 11           2022-06-30 08:55:13+00:00
# 12           2022-06-30 06:00:00+00:00
# 13           2022-06-30 04:57:42+00:00
# 14           2022-06-30 04:28:12+00:00
# 15           2022-06-29 17:49:35+00:00
# 16    2022-06-29 17:45:53.580000+00:00
# 17           2022-06-29 17:21:25+00:00
# 18           2022-06-29 17:02:39+00:00
# 19           2022-06-29 16:11:31+00:00
# 20           2022-06-29 15:05:41+00:00
# 21    2022-06-29 14:49:53.996000+00:00
# 22           2022-06-29 14:24:53+00:00
# ...

# %%
rs1 = df1['text'].apply(txt.flesch_kincaid_grade)

# %%
df1['read'] = rs1

# %%
df1.head()
# Out:
#               versionCreated  \
# 0  2022-06-30 15:30:01+00:00
# 1  2022-06-30 15:13:03+00:00
# 2  2022-06-30 13:49:00+00:00
# 3  2022-06-30 13:24:32+00:00
# 4  2022-06-30 13:14:03+00:00
#
#                                                 text  \
# 0  UPDATE 2-Biden supports F-16 sale to Turkey, i...
# 1  UPDATE 1-Nordic promises must be kept for Turk...
# 2            Interfax Russia & CIS Statistics Weekly
# 3  Biden supports F-16 sale to Turkey but needs c...
# 4  FACTBOX-NATO's plan to vastly increase combat-...
#
#                                         storyId sourceCode  read
# 0  urn:newsml:reuters.com:20220630:nL1N2YH1BH:7    NS:RTRS  10.3
# 1  urn:newsml:reuters.com:20220630:nL8N2YH5B7:2    NS:RTRS   8.8
# 2     urn:newsml:newsroom:20220707:nNRAl9c4r3:0     NS:IFX  12.3
# 3  urn:newsml:reuters.com:20220630:nW1N2XN03T:4    NS:RTRS   7.2
# 4  urn:newsml:reuters.com:20220630:nL8N2YH3BM:1    NS:RTRS   8.4

# %%
df1.to_csv(r'/Users/mertcakir/Downloads/turkeyout1.csv')

# %%
df2 = pd.read_csv('/Users/mertcakir/Desktop/tez python/texts/POLAND_1YEAR.csv')
rs2 = df2['text'].apply(txt.flesch_kincaid_grade)
df2['read'] = rs2
df2.to_csv(r'/Users/mertcakir/Downloads/polandout1.csv')

df3 = pd.read_csv('/Users/mertcakir/Desktop/tez python/texts/SAFRICA_1YEAR.csv')
rs3 = df3['text'].apply(txt.flesch_kincaid_grade)
df3['read'] = rs3
df3.to_csv(r'/Users/mertcakir/Downloads/safricaout1.csv')

df4 = pd.read_csv('/Users/mertcakir/Desktop/tez python/texts/INDONESIA_1YEAR.csv')
rs4 = df4['text'].apply(txt.flesch_kincaid_grade)
df4['read'] = rs4
df4.to_csv(r'/Users/mertcakir/Downloads/indonesiaout1.csv')

df5 = pd.read_csv('/Users/mertcakir/Desktop/tez python/texts/MEXICO_1YEAR.csv')
rs5 = df5['text'].apply(txt.flesch_kincaid_grade)
df5['read'] = rs5
df5.to_csv(r'/Users/mertcakir/Downloads/mexicoout1.csv')

# %%
# !pip install tensorflow
# Out:
# ...
#   Using cached tensorflow-2.11.0-cp37-cp37m-macosx_10_14_x86_64.whl (244.2 MB)
# ...
#   Using cached tensorboard-2.11.0-py3-none-any.whl (6.0 MB)
# ...
#   Using cached tensorflow_estimator-2.11.0-py2.py3-none-any.whl (439 kB)
# ...
#   Using cached google_pasta-0.2.0-py3-none-any.whl (57 kB)
# ...
#   Using cached h5py-3.7.0-cp37-cp37m-macosx_10_9_x86_64.whl (3.1 MB)
# ...
#   Using cached gast-0.4.0-py3-none-any.whl (9.8 kB)
# ...
#   Using cached libclang-14.0.6-py2.py3-none-macosx_10_9_x86_64.whl (13.2 MB)
# ...
#   Using cached keras-2.11.0-py2.py3-none-any.whl (1.7 MB)
# ...
#   Using cached tensorflow_io_gcs_filesystem-0.28.0-cp37-cp37m-macosx_10_14_x86_64.whl (1.6 MB)
# ...
#   Using cached absl_py-1.3.0-py3-none-any.whl (124 kB)
# ...
#   Using cached astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# ...
#   Using cached opt_einsum-3.3.0-py3-none-any.whl (65 kB)
# ...
#   Using cached protobuf-3.19.6-cp37-cp37m-macosx_10_9_x86_64.whl (979 kB)
# ...
#   Using cached grpcio-1.51.1-cp37-cp37m-macosx_10_10_x86_64.whl (4.6 MB)
# ...

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
import numpy as np

# %%
from tensorflow.keras.utils import to_categorical

# %%
data = pd.read_csv('/Users/mertcakir/Downloads/turkeyout12.csv')

# %%
data.head()
# Out:
#        Date      Read   Finbert  Label
# 0  7/1/2021  6.842857  0.571429      1
# 1  7/2/2021  5.350000  0.166667      0
# 2  7/5/2021  6.122222  0.555556      0
# 3  7/6/2021  4.733333  0.000000      1
# 4  7/7/2021  7.557143  0.428571      0

# %%
from tensorflow.keras.callbacks import EarlyStopping
early_stp_monitor = EarlyStopping(patience=2)
predictors=data.drop(['Label'], axis=1)
predictors=predictors.drop(['Date'], axis=1).values
target=to_categorical(data['Label'])
n_cols=predictors.shape[1]

# %%
predictors
# Out:
# array([[ 6.84285714,  0.57142857],
#        [ 5.35      ,  0.16666667],
#        [ 6.12222222,  0.55555556],
#        [ 4.73333333,  0.        ],
#        [ 7.55714286,  0.42857143],
#        [ 8.48571429,  0.57142857],
#        [ 6.93333333,  0.66666667],
#        [ 6.4       ,  0.2       ],
#        [ 8.78461539,  0.84615385],
#        [ 6.32      ,  0.4       ],
#        [10.475     ,  0.5       ],
#        [ 4.67142857,  0.71428571],
#        [ 7.8       ,  0.5       ],
#        [ 7.63333333,  0.66666667],
#        [ 6.58      ,  0.2       ],
#        [ 4.36666667,  0.66666667],
#        [ 7.        ,  0.2       ],
#        [ 5.4       ,  0.        ],
#        [ 6.475     ,  0.25      ],
#        [ 4.93333333,  0.33333333],
#        [ 8.9       ,  0.5       ],
#        [ 6.625     ,  0.5       ],
#        [ 7.46666667,  0.33333333],
#        [14.2       ,  0.        ],
#        [ 4.8       ,  0.5       ],
#        [ 6.71666667,  0.83333333],
#        [ 6.7       ,  0.33333333],
# ...

# %%
model = Sequential()
model.add(Dense(100, activation='relu', input_shape=(n_cols,)))
model.add(Dense(100, activation='relu'))
model.add(Dense(2, activation='softmax'))
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
model.fit(predictors, target, validation_split=0.3, epochs=20, callbacks = [early_stp_monitor])
# Out:
# Epoch 1/20
# 8/8 [==============================] - 1s 32ms/step - loss: 0.7035 - accuracy: 0.4602 - val_loss: 0.6923 - val_accuracy: 0.5510
# Epoch 2/20
# 8/8 [==============================] - 0s 10ms/step - loss: 0.7146 - accuracy: 0.5133 - val_loss: 0.6924 - val_accuracy: 0.5510
# Epoch 3/20
# 8/8 [==============================] - 0s 10ms/step - loss: 0.7042 - accuracy: 0.4646 - val_loss: 0.7426 - val_accuracy: 0.4490
